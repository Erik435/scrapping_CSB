# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
import os
import pandas as pd 
from io import StringIO
import numpy as np
from bs4 import BeautifulSoup

# %%
chromedriver_path = "chromedriver.exe"

# %%
# Inicializar el servicio de ChromeDriver
service = Service(chromedriver_path)
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.google.com")

# %%
URL = "https://www.amazon.com/s?k=laptops&__mk_es_US=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=1PT1MO3SZ1SE7&sprefix=laptop%2Caps%2C313&ref=nb_sb_noss_1"

# %%
driver.get(URL)

# %%
def get_html(url, selector, sleep_time=20):
    driver.get(url)
    time.sleep(sleep_time)
    element = driver.find_element(By.CSS_SELECTOR, selector) 
    return element.get_attribute("outerHTML")

# %%
html_content = get_html(URL, "#search > div.s-desktop-width-max.s-desktop-content.s-opposite-dir.s-wide-grid-style.sg-row > div.sg-col-20-of-24.s-matching-dir.sg-col-16-of-20.sg-col.sg-col-8-of-12.sg-col-12-of-16 > div > span.rush-component.s-latency-cf-section > div.s-main-slot.s-result-list.s-search-results.sg-row")

# %%
soup = BeautifulSoup(html_content, "html.parser")

# %%
h2_tags = soup.find_all("h2", attrs={"aria-label": True})

# %%
for tag in h2_tags:
    print(tag["aria-label"])
# Out:
# HP Portátil Pavilion con pantalla táctil de 15.6 pulgadas • Edición 2026 • AMD Ryzen 5 7520U • 8GB RAM • 256GB PCle SSD • Bluetooth • Copilot AI • Wi-Fi 6 • Windows 11 • Listo para la escuela y el
# HP Laptop de 17 pulgadas edición 2026, 16 GB de RAM 256 GB SSD, CPU Intel 13th i3 (8 núcleos), pantalla IPS de 17.3 pulgadas, pantalla grande, Windows 11 con Office 365 para la web, sin mouse
# Anuncio Patrocinado - Acer Aspire Go 15 AI Ready Laptop | Pantalla IPS FHD de 15.6 pulgadas (1920 x 1080), procesador Intel Core 3 N355, gráficos Intel, DDR5 de 8 GB, UFS de 128 GB, Wi-Fi 6, Windows 11 Home en modo S, AG15
# Anuncio Patrocinado - HP Chromebook Thin Laptop Student Business 2024, pantalla HD de 14 pulgadas, procesador Intel Celeron N4120 de cuatro núcleos, 4 GB de RAM, 64 GB eMMC, cámara web HD, WiFi, batería larga, Chrome OS + HubxcelAccesorio Gris
# Anuncio Patrocinado - Lenovo Chromebook 14" Laptop Slim con Pantalla Táctil para Negocios y Estudiantes, Procesador de 8 Núcleos MediaTek Kompanio 520, 4 GB RAM, 128 GB de Almacenamiento (64 GB eMMC + Tarjeta de 64 GB
# Anuncio Patrocinado - Lenovo Legion Pro 7i – Portátil para juegos – Intel® Core™ Ultra 9 275HX – Pantalla OLED WQXGA 2.5K de 16" – Frecuencia de actualización de 240Hz – GPU GeForce RTX™ 5070 Ti – 32 GB de memoria – 1 TB
# Anuncio Patrocinado - Coolby Portátil de 15.6 pulgadas, 12 GB de RAM/256 GB SSD, pantalla IPS de 1920 x 1080, Intel N95 (Beats N5095) Computadora portátil de cuatro núcleos, compatible con huellas dactilares, WiFi 5, BT
# HP 14 portátil, Intel Celeron N4020, 4 GB de RAM, 64 GB de almacenamiento, pantalla Micro-edge HD de 14 pulgadas, Windows 11 Home, delgada y portátil, gráficos 4K, un año de Microsoft 365 (14-dq0040nr
# HP Laptop FHD de 15.6 pulgadas edición 2026 con IA Copilot, 16 GB de RAM, SSD de 512 GB, procesador Intel, batería de larga duración, ligera 3.64 libras, Microsoft 365, Windows 11 para estudiantes y
# Laptop Dell 15 DC15250 - pantalla FHD de 15.6 pulgadas 120Hz, procesador Intel Core 3 100U, 8 GB DDR4 RAM, SSD de 512 GB, gráficos Intel UHD, Windows 11 Home, servicio in situ - negro carbón
# HP Computadora portátil empresarial de 14 pulgadas, Microsoft Office 365 con Copilot AI y OneDrive de 1 TB, 16 GB de RAM y 320 GB de almacenamiento (256 GB SSD+64 GB eMMC), procesador Intel de doble núcleo, Win 11, auriculares PLUSERA, oro rosa, mejor valor
# KAIGERR Nueva computadora portátil para juegos 2026, computadora portátil de 16.0 pulgadas con AMD Ryzen 7 H255 (8C/16T, hasta 4.9 GHz), 16 GB DDR5 512 GB NVMe SSD Windows 11, Radeon RX Vega 8
# Portátil portátil de 16 pulgadas 8GB DDR 256GB SSD, ampliable a 1 TB, CPU AMD A9-9400 Radeon R5 hasta 3,2 GHz, batería de 9000 mAh, teclado numérico, USB 3.0, WiFi de doble banda, cámara web, portátiles delgados
# HP 255 G10 - Laptop empresarial FHD de 15.6 pulgadas, AMD Ryzen 7 7730U, 16 GB de RAM, SSD PCIe de 512 GB, teclado numérico, cámara web, Wi-Fi 6, HDMI, Windows 11 Pro, negro
# HP Stream - Laptop BrightView HD de 14 pulgadas, Intel Celeron N150, 16 GB de RAM, 288 GB de almacenamiento (128 GB eMMC + 160 GB conjunto de estación de acoplamiento), gráficos Intel UHD, cámara web
# Acer Aspire Go 15 AI Ready Laptop | Pantalla IPS FHD de 15.6 pulgadas (1920 x 1080), procesador Intel Core 3 N355, gráficos Intel, DDR5 de 8 GB, UFS de 128 GB, Wi-Fi 6, Windows 11 Home en modo S, AG15
# Dell Latitude 5400 Laptop | 14 pulgadas 1920x1080 FHD | Core i5-8365U - Disco duro SSD de 256 GB - 8 GB de RAM | 4 núcleos @ 4.1 GHz Win 11 Pro (renovado), negro
# Dell 15 Laptop DC15250 - Pantalla FHD de 15.6 pulgadas (1920x1080) 120Hz, procesador Intel Core i5-1334U, 16 GB de RAM DDR4, SSD de 512 GB, gráficos Intel UHD, Windows 11 Home, servicio in situ
# HP Flagship Business Laptop con pantalla FHD IPS de 15.6 pulgadas, AMD Ryzen 7 7730U, 16 GB de RAM y SSD PCle de 512 GB, Windows 11 Pro, Copilot AI, WiFi 6, Bluetooth, teclado numérico, con accesorio
# ASUS ROG Strix G16 (2025) portátil para juegos, pantalla FHD+ de 16” 16:10 165Hz/3ms, unidad de procesamiento de gráficos GeForce RTX™ 5060, procesador Intel® Core™ i7 14650HX, 16 GB DDR5, SSD Gen 4
# HP Ultrabook Laptop • Microsoft 365 1 año incluido • 8 GB de RAM • Intel 13 de 4 núcleos N100 • 1 TB en la nube y 128 GB de almacenamiento SSD • Win 11 • sin mouse • Astilla | Desempeño esencial y suave para todos los días

# %%
for a in soup.find_all("a"):
    if a.find("span", class_="a-offscreen"):
        print(a.find("span", class_="a-offscreen").get_text())
# Out:
# US$334.99
# US$186.95
# US$247.00
# US$2,249.99
# US$259.00
# US$194.95
# US$539.99
# US$229.99
# 5 capacidades
# US$556.89
# 2 capacidades
# US$328.99
# US$334.99
# US$169.99
# US$1,399.99
# Todo lo que necesitas para la universidad. Todo en un paquete.
# Premium Office Apps, Cloud Storage, and Security
# MacBook Neo. Una Mac increíble. Un precio sorprendente.
